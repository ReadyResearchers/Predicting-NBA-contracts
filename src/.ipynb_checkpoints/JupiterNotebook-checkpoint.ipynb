# %%
import matplotlib.pyplot as plt
from sklearn import linear_model
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import datasets, linear_model

#read in data
df1 = pd.read_csv('data/SPOTRAC.csv')
df1.sort_values(['Player'], 
                    axis=0,
					ascending=[True],
                    inplace=True)
Y = df1['Ave Salary']
X = df1['VORP_0']
X_1 = df1['Age']
df1.head(10)
# Out:
#               Player Pos    Age Type FROM   TO  Years      Value  Ave Salary  \
# 94     Aaron Holiday  PG  25.8>  UFA  PHX  ATL      1    1968175     1968175
# 36       Amir Coffey  SG  25.0>  RFA  LAC  LAC      3   11000000     3666667
# 42    Andre Drummond   C  28.8>  UFA  BKN  CHI      2    6560000     3280000
# 64    Andre Iguodala  SF  38.6>  UFA  GSW  GSW      1    2905851     2905851
# 4    Anfernee Simons  SG  23.0>  RFA  POR  POR      4  100000000    25000000
# 60      Anthony Gill  PF  29.7>  RFA  WAS  WAS      2    3833328     1916664
# 108     Anthony Lamb  SF  24.7>  UFA  HOU  GSW      1    1836090     1836090
# 67     Austin Rivers  PG  29.9>  UFA  DEN  MIN      1    2905851     2905851
# 73   Bismack Biyombo   C  29.8>  UFA  PHX  PHX      1    2905851     2905851
# 63     Blake Griffin  PF  33.5>  UFA  BKN  BOS      1    2905851     2905851
#
#      Max Value  ...  Year _2  Count Records 0  Count Records 1  \
# ...

# %%
df1['VORP_1']
# Out:
# 94    -0.7
# 36     0.0
# 42     0.3
# 64     0.5
# 4      0.3
#       ...
# 41     0.0
# 72     0.1
# 120    0.0
# 92     0.2
# 1      3.1
# Name: VORP_1, Length: 122, dtype: float64

# %%
X_1
# Out:
# 94     25.8>
# 36     25.0>
# 42     28.8>
# 64     38.6>
# 4      23.0>
#        ...
# 41     25.2>
# 72     35.7>
# 120    27.5>
# 92     27.8>
# 1      27.2>
# Name: Age, Length: 122, dtype: object

# %%
df1['Ave Salary']
# Out:
# 94      1968175
# 36      3666667
# 42      3280000
# 64      2905851
# 4      25000000
#          ...
# 41      2271775
# 72      2905851
# 120     1637966
# 92      1968175
# 1      43031940
# Name: Ave Salary, Length: 122, dtype: int64

# %%
two_d_Array =df1[{'VORP_0', 'VORP_1'}].to_numpy()
# Out:
# /var/folders/hw/6bzkhxpn51x7n21dhhj4lc200000gn/T/ipykernel_11295/2008248024.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   two_d_Array =df1[{'VORP_0', 'VORP_1'}].to_numpy()

# %%
vector = np.vectorize(np.float)
# Out:
# /var/folders/hw/6bzkhxpn51x7n21dhhj4lc200000gn/T/ipykernel_11295/2829588490.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   vector = np.vectorize(np.float)

# %%
two_d_Array = vector(two_d_Array)

# %%
two_d_Array
# Out:
# array([[-0.7,  0.1],
#        [ 0. ,  0.7],
#        [ 0.3,  1.2],
#        [ 0.5,  0.7],
#        [ 0.3,  0.5],
#        [ 0. ,  0. ],
#        [-0.4,  0. ],
#        [ 0. , -0.7],
#        [-0.4,  0.1],
#        [ 0.3,  0.3],
#        [ 1.2,  1.1],
#        [-0.1,  0. ],
#        [ 2.9,  1. ],
#        [-0.2,  0. ],
#        [ 0.7,  1.2],
#        [ 0.2, -0.3],
#        [-0.1, -1. ],
#        [-0.3,  1.1],
#        [ 2. ,  0.9],
#        [ 0.1, -0.4],
#        [ 0. ,  0.7],
#        [ 1. , -0.2],
#        [-0.1,  0.1],
#        [ 0.1,  0.6],
#        [ 0.6,  0. ],
#        [ 1. ,  0.8],
#        [-0.3,  0.2],
#        [ 0. ,  0. ],
#        [ 0. ,  0.3],
#        [ 0.9,  0.1],
#        [ 1.7,  2.1],
#        [ 1.8,  1.6],
#        [ 0.4,  0. ],
#        [ 0.2,  0.2],
#        [ 0. ,  0.2],
#        [ 0.2,  0.3],
#        [ 1. , -0.1],
#        [ 0.4,  0.2],
#        [ 0. , -0.5],
#        [ 0.5,  0.4],
#        [ 0.1, -0.4],
#        [ 0.6,  0.3],
#        [ 0. ,  0. ],
# ...

# %%
#res = [float(i) for i in two_d_Array]

# %%
#two_d_list = list(two_d_Array)

# %%
#two_d_list

# %%
df1['A'] = two_d_Array.tolist()

# %%
df1.head(10)
# Out:
#               Player Pos    Age Type FROM   TO  Years      Value  Ave Salary  \
# 94     Aaron Holiday  PG  25.8>  UFA  PHX  ATL      1    1968175     1968175
# 36       Amir Coffey  SG  25.0>  RFA  LAC  LAC      3   11000000     3666667
# 42    Andre Drummond   C  28.8>  UFA  BKN  CHI      2    6560000     3280000
# 64    Andre Iguodala  SF  38.6>  UFA  GSW  GSW      1    2905851     2905851
# 4    Anfernee Simons  SG  23.0>  RFA  POR  POR      4  100000000    25000000
# 60      Anthony Gill  PF  29.7>  RFA  WAS  WAS      2    3833328     1916664
# 108     Anthony Lamb  SF  24.7>  UFA  HOU  GSW      1    1836090     1836090
# 67     Austin Rivers  PG  29.9>  UFA  DEN  MIN      1    2905851     2905851
# 73   Bismack Biyombo   C  29.8>  UFA  PHX  PHX      1    2905851     2905851
# 63     Blake Griffin  PF  33.5>  UFA  BKN  BOS      1    2905851     2905851
#
#      Max Value  ...  Count Records 0  Count Records 1  Count Records 2  \
# ...

# %%
# Split the data into training/testing sets
X_train = np.array(X[:-25],A[:-25])
X_test = np.array(X[-25:], A[-25:])

# X_1_train = np.array(X_1[:-25])
# X_1_test = np.array(X_1[-25:])
# Split the targets into training/testing sets
y_train = np.array(Y[:-25])
y_test = np.array(Y[-25:])


X_train
# Out:
# /var/folders/hw/6bzkhxpn51x7n21dhhj4lc200000gn/T/ipykernel_11295/1290903832.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   X_train = np.array(X[:-25],A[:-25])
# /var/folders/hw/6bzkhxpn51x7n21dhhj4lc200000gn/T/ipykernel_11295/1290903832.py:3: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   X_test = np.array(X[-25:], A[-25:])
# ...

# %%
X_train = X_train[:, np.newaxis]
X_train
X_test = X_test[:, np.newaxis]
X_test
type(X_test)
# Out:
# numpy.ndarray

# %%
plt.scatter(X,Y, color = 'black')
plt.xlabel('VORP_0')
plt.ylabel('Salaries')
plt.xticks(())
plt.yticks(())
plt.show()

# %%
df1.corr()
# Out:
# /var/folders/hw/6bzkhxpn51x7n21dhhj4lc200000gn/T/ipykernel_11295/473017434.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#                     Years     Value  Ave Salary  Max Value  Year  Year_1  \
# Years            1.000000  0.751096    0.721733   0.752722   NaN     NaN
# Value            0.751096  1.000000    0.960471   0.999932   NaN     NaN
# Ave Salary       0.721733  0.960471    1.000000   0.960830   NaN     NaN
# Max Value        0.752722  0.999932    0.960830   1.000000   NaN     NaN
# Year                  NaN       NaN         NaN        NaN   NaN     NaN
# Year_1                NaN       NaN         NaN        NaN   NaN     NaN
# Year _2               NaN       NaN         NaN        NaN   NaN     NaN
# Count Records 0  0.101594  0.058604    0.055681   0.059022   NaN     NaN
# ...

# %%
print(y_train)
# Out:
# [ 1968175  3666667  3280000  2905851 25000000  1916664  1836090  2905851
#   2905851  2905851 12144552  2200000 50203930  1836090  6640975  2298385
#   1836090  6802950 11750000  1968175  7840000 17737500  2273291  2442525
#   2133278  6640975  4207625  1637966  1984359  2905851 33232282  8000000
#   2641682  3280000  1902133  4512000  4612500  1968175  1836090  1836090
#   2133278  2463490  1637966  8715000  2905851  2641682  8000000  2628597
#   5734280  6876811  2298385 26000000  5043773 34320000  1637966  1836090
#   1886069  2169972  6479000  2187500  6640975  2900000  2133278  1968175
#   1902133  2298385  1782931 17500000  1984359  1782931  3000000  7500000
#   9000000  1637966  6479000  1836090 16500000  2273291  1836090  9709025
#  12500000  1637966  2628597  1637966  3500000 15000000 10300000  2611758
#   1902133  1902133  1836090  1916664 11277084  8625000  6150000 11014500
#   6640975]

# %%
regr = linear_model.LinearRegression()
# Train the model using the training sets
regr.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 3
#       1 regr = linear_model.LinearRegression()
#       2 # Train the model using the training sets
# ----> 3 regr.fit(X_train, y_train)
#
# File /usr/local/lib/python3.10/site-packages/sklearn/linear_model/_base.py:649, in LinearRegression.fit(self, X, y, sample_weight)
#     645 n_jobs_ = self.n_jobs
#     647 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 649 X, y = self._validate_data(
#     650     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     651 )
#     653 sample_weight = _check_sample_weight(
#     654     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     655 )
#     657 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     658     X,
#     659     y,
#    (...)
#     662     sample_weight=sample_weight,
#     663 )
#
# ...

# %%
# Make predictions using the testing set
y_pred = regr.predict(X_test)
print(y_pred)
# Out:
# [ 1514639.89913456  4387646.40875809  6686051.61645691  3238443.80490867
#   2089241.20105926  4387646.40875809  3238443.80490867  4962247.71068279
#   4387646.40875809  3238443.80490867  3813045.10683338  3813045.10683338
#   3813045.10683338  4387646.40875809  4387646.40875809  4387646.40875809
#   3238443.80490867 11857463.33377925  3238443.80490867  4387646.40875809
#   3813045.10683338  2089241.20105926  4387646.40875809  3813045.10683338
#  18752678.95687572]

# %%
X_test
# Out:
# array([[-0.4],
#        [ 0.1],
#        [ 0.5],
#        [-0.1],
#        [-0.3],
#        [ 0.1],
#        [-0.1],
#        [ 0.2],
#        [ 0.1],
#        [-0.1],
#        [ 0. ],
#        [ 0. ],
#        [ 0. ],
#        [ 0.1],
#        [ 0.1],
#        [ 0.1],
#        [-0.1],
#        [ 1.4],
#        [-0.1],
#        [ 0.1],
#        [ 0. ],
#        [-0.3],
#        [ 0.1],
#        [ 0. ],
#        [ 2.6]])

# %%
df1['VORP_0']
# Out:
# 94     0.1
# 36     0.7
# 42     1.2
# 64     0.7
# 4      0.5
#       ...
# 41     0.0
# 72    -0.3
# 120    0.1
# 92     0.0
# 1      2.6
# Name: VORP_0, Length: 122, dtype: float64

# %%
# The coefficients
print("Coefficients: \n", regr.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))

# Plot outputs
plt.scatter(X_test, y_test, color="black")
plt.plot(X_test, y_pred, color="blue", linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Coefficients:
#  [5746013.01924705]
# Mean squared error: 27492329113328.68
# Coefficient of determination: 0.60

# %%
from sklearn import linear_model

# %%
from sklearn.linear_model import Lasso
lasso = Lasso(alpha = 1.0)

# %%
lasso.fit(X_train, y_train)
# Out:
# Lasso()

# %%
y_pred = lasso.predict(X_test)

# %%
 y_pred
# Out:
# array([ 1514641.26404017,  4387646.91506548,  6686051.43588574,
#         3238444.65465536,  2089242.39424523,  4387646.91506548,
#         3238444.65465536,  4962248.04527055,  4387646.91506548,
#         3238444.65465536,  3813045.78486042,  3813045.78486042,
#         3813045.78486042,  4387646.91506548,  4387646.91506548,
#         4387646.91506548,  3238444.65465536, 11857461.60773131,
#         3238444.65465536,  4387646.91506548,  3813045.78486042,
#         2089242.39424523,  4387646.91506548,  3813045.78486042,
#        18752675.17019207])

# %%
print("Slope: %.2f" % lasso.coef_[0])
# Out:
# Slope: 5746011.30

# %%
print("Intercept: %.2f" % lasso.intercept_)
# Out:
# Intercept: 3813045.78

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_pred)
# Out:
# 27492337898495.746

# %%
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# Coefficient of determination: 0.60
